# %% [markdown]
# # Deferred Acceptance Algorithm Walkthrough

# %% [markdown]
# This is a walkthough and explanation of the deferred acceptance algorithm, aka Gale–Shapley algorithm. In this implementation, we have a heteronormative village in which 8 men and 8 women must marry to each other.

# %%
# these are our men and women

men = [
    "aaron",
    "brad",
    "charles",
    "david",
    "edward",
    "frank",
    "greg",
    "harry",
]

women = [
    "alice",
    "betty",
    "claire",
    "donna",
    "esther",
    "fay",
    "grace",
    "holly",
]

# %%
# a dictionary of lists of preferences, in order of preference for each person

prefs = {
    # women
    "alice": ['frank', 'greg', 'aaron', 'brad', 'charles', 'edward', 'david', 'harry'],
    "betty": ['charles', 'aaron', 'brad', 'greg', 'edward', 'frank', 'david', 'harry'],
    "claire": ['edward', 'charles', 'frank', 'aaron', 'david', 'brad', 'greg', 'harry'],
    "donna": ['brad', 'greg', 'frank', 'aaron', 'edward', 'david', 'harry', 'charles'],
    "esther": ['brad', 'aaron', 'charles', 'frank', 'greg', 'david', 'harry', 'edward'],
    "fay": ['edward', 'greg', 'david', 'brad', 'harry', 'frank', 'charles', 'aaron'],
    "grace": ['david', 'frank', 'brad', 'harry', 'greg', 'edward', 'aaron', 'charles'],
    "holly": ['greg', 'edward', 'charles', 'frank', 'harry', 'aaron', 'brad', 'david'],
    # men
    "aaron": ['holly', 'fay', 'donna', 'grace', 'betty', 'esther', 'claire', 'alice'],
    "brad": ['claire', 'betty', 'esther', 'alice', 'grace', 'holly', 'donna', 'fay'],
    "charles": ['betty', 'holly', 'alice', 'donna', 'fay', 'grace', 'claire', 'esther'],
    "david": ['grace', 'holly', 'esther', 'betty', 'claire', 'alice', 'fay', 'donna'],
    "edward": ['claire', 'betty', 'fay', 'esther', 'grace', 'donna', 'holly', 'alice'],
    "frank": ['betty', 'claire', 'esther', 'grace', 'fay', 'alice', 'holly', 'donna'],
    "greg": ['claire', 'fay', 'alice', 'holly', 'esther', 'betty', 'grace', 'donna'],
    "harry": ['betty', 'alice', 'claire', 'donna', 'holly', 'fay', 'esther', 'grace'],
}

# %%
# let's keep the matches in a dictionary with women as keys

matches = {
    "alice": None,
    "betty": None,
    "claire": None,
    "donna": None,
    "esther": None,
    "fay": None,
    "grace": None,
    "holly": None,
}

# %%
# we will also keep a list of women that have been rejected by each man

exclusions = {
    "aaron": [],
    "brad": [],
    "charles": [],
    "david": [],
    "edward": [],
    "frank": [],
    "greg": [],
    "harry": [],
}

# %%
# we need two helper functions, one is get_top_preference, which returns the next highest
# preference of a woman's, after taking into consideration men's exclusions/rejections

def get_top_preference(woman):
    for man in prefs[woman]:
        if woman in exclusions[man]:
            print(f"{woman} has already been rejected by {man}")
            continue
        else:
            print(f"{woman}'s preference is {man}")
            return man

    # if there is no man who has not been excluded and is no match
    raise ValueError(f"no more men left for {woman}")

# %%
# second helper function is get_man_match which finds the woman that likes a given man

def get_man_match(given_man):
    for woman, man in matches.items():
        if man == given_man:
            return woman

    raise ValueError(f"{man} is not matched with any woman")

# %%
# we make a fresh copy of the women list, to keep track which have matched and which haven't
free_women = women.copy()

# while free women list is not empty
while free_women:

    print(f"free_women={list(reversed(free_women))}")
    woman = free_women.pop()

    print(f"{woman}'s turn")
    man = get_top_preference(woman)

    # if woman's preference is already matched
    if man in matches.values():

        # find woman with which our current man is matched
        current_match = get_man_match(man)
        print(f"{man} is currently matched with {current_match}")

        # find how high is current in man's list
        current_woman_index = prefs[man].index(current_match)
        print(f"{current_woman_index=}")

        # find how high in his list is the woman who now proposes to man
        new_woman_index = prefs[man].index(woman)
        print(f"{new_woman_index=}")

        # if new woman is prioritised higher
        if new_woman_index < current_woman_index:

            # add previous woman to man's rejection list
            print(f"{woman} is higher in {man}'s list, switching")
            exclusions[man].append(current_match)
            print(f"adding {current_match} to {man}'s exclusion list: {exclusions[man]}")
            
            # switch matches
            matches[woman] = man
        else:

            # add current woman to man's rejection list
            print(f"{woman} is lower in {man}'s list, ignored by {man}")
            exclusions[man].append(woman)
            print(f"add {woman} to {man}'s exclusion list: {exclusions[man]}")
            free_women.insert(0, woman)
            print(f"put {woman} back on free_women list")

    else:
        # woman's preference is free, we assume they accept
        print(f"{man} is available, matching with {woman}")
        matches[woman] = man

    print()

print(matches)
# Out:
# free_women=['holly', 'grace', 'fay', 'esther', 'donna', 'claire', 'betty', 'alice']
# holly's turn
# holly's preference is greg
# greg is currently matched with holly
# current_woman_index=3
# new_woman_index=3
# holly is lower in greg's list, ignored by greg
# add holly to greg's exclusion list: ['donna', 'holly']
# put holly back on free_women list
#
# free_women=['grace', 'fay', 'esther', 'donna', 'claire', 'betty', 'alice', 'holly']
# grace's turn
# grace's preference is david
# david is currently matched with grace
# current_woman_index=0
# new_woman_index=0
# grace is lower in david's list, ignored by david
# add grace to david's exclusion list: ['grace']
# put grace back on free_women list
#
# free_women=['fay', 'esther', 'donna', 'claire', 'betty', 'alice', 'holly', 'grace']
# fay's turn
# fay has already been rejected by edward
# fay's preference is greg
# greg is currently matched with holly
# current_woman_index=3
# new_woman_index=1
# fay is higher in greg's list, switching
# adding holly to greg's exclusion list: ['donna', 'holly', 'holly']
#
# free_women=['esther', 'donna', 'claire', 'betty', 'alice', 'holly', 'grace']
# esther's turn
# esther's preference is brad
# brad is currently matched with esther
# current_woman_index=2
# new_woman_index=2
# esther is lower in brad's list, ignored by brad
# add esther to brad's exclusion list: ['donna', 'esther']
# put esther back on free_women list
#
# free_women=['donna', 'claire', 'betty', 'alice', 'holly', 'grace', 'esther']
# donna's turn
# donna has already been rejected by brad
# donna has already been rejected by greg
# donna has already been rejected by frank
# donna's preference is aaron
# aaron is currently matched with donna
# current_woman_index=2
# new_woman_index=2
# donna is lower in aaron's list, ignored by aaron
# add donna to aaron's exclusion list: ['donna']
# put donna back on free_women list
#
# free_women=['claire', 'betty', 'alice', 'holly', 'grace', 'esther', 'donna']
# claire's turn
# claire's preference is edward
# edward is currently matched with claire
# current_woman_index=0
# new_woman_index=0
# claire is lower in edward's list, ignored by edward
# add claire to edward's exclusion list: ['fay', 'claire']
# put claire back on free_women list
#
# free_women=['betty', 'alice', 'holly', 'grace', 'esther', 'donna', 'claire']
# betty's turn
# betty's preference is charles
# charles is currently matched with betty
# current_woman_index=0
# new_woman_index=0
# betty is lower in charles's list, ignored by charles
# add betty to charles's exclusion list: ['betty']
# put betty back on free_women list
#
# free_women=['alice', 'holly', 'grace', 'esther', 'donna', 'claire', 'betty']
# alice's turn
# alice's preference is frank
# frank is currently matched with alice
# current_woman_index=5
# new_woman_index=5
# alice is lower in frank's list, ignored by frank
# add alice to frank's exclusion list: ['donna', 'alice']
# put alice back on free_women list
#
# free_women=['holly', 'grace', 'esther', 'donna', 'claire', 'betty', 'alice']
# holly's turn
# holly has already been rejected by greg
# holly's preference is edward
# edward is currently matched with claire
# current_woman_index=0
# new_woman_index=6
# holly is lower in edward's list, ignored by edward
# add holly to edward's exclusion list: ['fay', 'claire', 'holly']
# put holly back on free_women list
#
# free_women=['grace', 'esther', 'donna', 'claire', 'betty', 'alice', 'holly']
# grace's turn
# grace has already been rejected by david
# grace's preference is frank
# frank is currently matched with alice
# current_woman_index=5
# new_woman_index=3
# grace is higher in frank's list, switching
# adding alice to frank's exclusion list: ['donna', 'alice', 'alice']
#
# free_women=['esther', 'donna', 'claire', 'betty', 'alice', 'holly']
# esther's turn
# esther has already been rejected by brad
# esther's preference is aaron
# aaron is currently matched with donna
# current_woman_index=2
# new_woman_index=5
# esther is lower in aaron's list, ignored by aaron
# add esther to aaron's exclusion list: ['donna', 'esther']
# put esther back on free_women list
#
# free_women=['donna', 'claire', 'betty', 'alice', 'holly', 'esther']
# donna's turn
# donna has already been rejected by brad
# donna has already been rejected by greg
# donna has already been rejected by frank
# donna has already been rejected by aaron
# donna's preference is edward
# edward is currently matched with claire
# current_woman_index=0
# new_woman_index=5
# donna is lower in edward's list, ignored by edward
# add donna to edward's exclusion list: ['fay', 'claire', 'holly', 'donna']
# put donna back on free_women list
#
# free_women=['claire', 'betty', 'alice', 'holly', 'esther', 'donna']
# claire's turn
# claire has already been rejected by edward
# claire's preference is charles
# charles is currently matched with betty
# current_woman_index=0
# new_woman_index=6
# claire is lower in charles's list, ignored by charles
# add claire to charles's exclusion list: ['betty', 'claire']
# put claire back on free_women list
#
# free_women=['betty', 'alice', 'holly', 'esther', 'donna', 'claire']
# betty's turn
# betty has already been rejected by charles
# betty's preference is aaron
# aaron is currently matched with donna
# current_woman_index=2
# new_woman_index=4
# betty is lower in aaron's list, ignored by aaron
# add betty to aaron's exclusion list: ['donna', 'esther', 'betty']
# put betty back on free_women list
#
# free_women=['alice', 'holly', 'esther', 'donna', 'claire', 'betty']
# alice's turn
# alice has already been rejected by frank
# alice's preference is greg
# greg is currently matched with fay
# current_woman_index=1
# new_woman_index=2
# alice is lower in greg's list, ignored by greg
# add alice to greg's exclusion list: ['donna', 'holly', 'holly', 'alice']
# put alice back on free_women list
#
# free_women=['holly', 'esther', 'donna', 'claire', 'betty', 'alice']
# holly's turn
# holly has already been rejected by greg
# holly has already been rejected by edward
# holly's preference is charles
# charles is currently matched with betty
# current_woman_index=0
# new_woman_index=1
# holly is lower in charles's list, ignored by charles
# add holly to charles's exclusion list: ['betty', 'claire', 'holly']
# put holly back on free_women list
#
# free_women=['esther', 'donna', 'claire', 'betty', 'alice', 'holly']
# esther's turn
# esther has already been rejected by brad
# esther has already been rejected by aaron
# esther's preference is charles
# charles is currently matched with betty
# current_woman_index=0
# new_woman_index=7
# esther is lower in charles's list, ignored by charles
# add esther to charles's exclusion list: ['betty', 'claire', 'holly', 'esther']
# put esther back on free_women list
#
# free_women=['donna', 'claire', 'betty', 'alice', 'holly', 'esther']
# donna's turn
# donna has already been rejected by brad
# donna has already been rejected by greg
# donna has already been rejected by frank
# donna has already been rejected by aaron
# donna has already been rejected by edward
# donna's preference is david
# david is available, matching with donna
#
# free_women=['claire', 'betty', 'alice', 'holly', 'esther']
# claire's turn
# claire has already been rejected by edward
# claire has already been rejected by charles
# claire's preference is frank
# frank is currently matched with alice
# current_woman_index=5
# new_woman_index=1
# claire is higher in frank's list, switching
# adding alice to frank's exclusion list: ['donna', 'alice', 'alice', 'alice']
#
# free_women=['betty', 'alice', 'holly', 'esther']
# betty's turn
# betty has already been rejected by charles
# betty has already been rejected by aaron
# betty's preference is brad
# brad is currently matched with esther
# current_woman_index=2
# new_woman_index=1
# betty is higher in brad's list, switching
# adding esther to brad's exclusion list: ['donna', 'esther', 'esther']
#
# free_women=['alice', 'holly', 'esther']
# alice's turn
# alice has already been rejected by frank
# alice has already been rejected by greg
# alice's preference is aaron
# aaron is available, matching with alice
#
# free_women=['holly', 'esther']
# holly's turn
# holly has already been rejected by greg
# holly has already been rejected by edward
# holly has already been rejected by charles
# holly's preference is frank
# frank is currently matched with claire
# current_woman_index=1
# new_woman_index=6
# holly is lower in frank's list, ignored by frank
# add holly to frank's exclusion list: ['donna', 'alice', 'alice', 'alice', 'holly']
# put holly back on free_women list
#
# free_women=['esther', 'holly']
# esther's turn
# esther has already been rejected by brad
# esther has already been rejected by aaron
# esther has already been rejected by charles
# esther's preference is frank
# frank is currently matched with claire
# current_woman_index=1
# new_woman_index=2
# esther is lower in frank's list, ignored by frank
# add esther to frank's exclusion list: ['donna', 'alice', 'alice', 'alice', 'holly', 'esther']
# put esther back on free_women list
#
# free_women=['holly', 'esther']
# holly's turn
# holly has already been rejected by greg
# holly has already been rejected by edward
# holly has already been rejected by charles
# holly has already been rejected by frank
# holly's preference is harry
# harry is available, matching with holly
#
# free_women=['esther']
# esther's turn
# esther has already been rejected by brad
# esther has already been rejected by aaron
# esther has already been rejected by charles
# esther has already been rejected by frank
# esther's preference is greg
# greg is currently matched with fay
# current_woman_index=1
# new_woman_index=4
# esther is lower in greg's list, ignored by greg
# add esther to greg's exclusion list: ['donna', 'holly', 'holly', 'alice', 'esther']
# put esther back on free_women list
#
# free_women=['esther']
# esther's turn
# esther has already been rejected by brad
# esther has already been rejected by aaron
# esther has already been rejected by charles
# esther has already been rejected by frank
# esther has already been rejected by greg
# esther's preference is david
# david is currently matched with donna
# current_woman_index=7
# new_woman_index=2
# esther is higher in david's list, switching
# adding donna to david's exclusion list: ['grace', 'donna']
#
# {'alice': 'aaron', 'betty': 'brad', 'claire': 'frank', 'donna': 'david', 'esther': 'david', 'fay': 'greg', 'grace': 'frank', 'holly': 'harry'}
